# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import mpl_toolkits
# %matplotlib inline

# %%
df = pd.read_csv("kc_house_data.csv")

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %% [markdown]
# # How common factors affect the price of a house?

# %% [markdown]
# ## Bedrooms

# %% [markdown]
# ### What is the most common number of bedrooms in a house?

# %%
df['bedrooms'].value_counts().plot(kind='bar', figsize=(15,5))
plt.title('Number of Bedrooms')
plt.xticks(rotation=0)
plt.xlabel('Bedrooms')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# We can see that the highest number of houses sold are those with three bedrooms, followed by those with four bedrooms. There are houses with more than 6 bedrooms, but they are very few.

# %% [markdown]
# ### How the price is affected by the number of bedrooms?

# %%
plt.figure(figsize=(12, 8))
plt.scatter(df.bedrooms, df.price, edgecolors='white', s=100)
plt.title("Bedroom vs Price ")
plt.ticklabel_format(style='plain')
plt.xlabel("Bedrooms")
plt.ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %% [markdown]
# The price of the house increases as the number of bedrooms increases. The most expensive ones are those with 5 and 6 rooms. However, there are houses with 33 bedrooms that are cheaper than houses with 11 bedrooms. This is because the price of a house depends on other factors as well.

# %% [markdown]
# ## Floors

# %% [markdown]
# ### What is the most common number of floors in a house?

# %%
df.floors.value_counts().plot(kind='bar', figsize=(15,5))
plt.title('Number of Floors')
plt.xticks(rotation=0)
plt.xlabel('Floors')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# Most houses have 1 floor, followed by 2 floors. There are houses with 3 floors, but they are very few.

# %% [markdown]
# ### How the price is affected by the number of floors?

# %%
plt.figure(figsize=(12, 8))
plt.scatter(df.floors, df.price, edgecolors='white', s=100)
plt.title("Floors vs Price ")
plt.ticklabel_format(style='plain')
plt.xlabel("Floors")
plt.ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %% [markdown]
# The price of the house increases as the number of floors increases. The most expensive ones are those with 3 floors.

# %% [markdown]
# ## Square Feet

# %% [markdown]
# ### How the price is affected by the square feet (living) of the house?

# %%
plt.figure(figsize=(12, 8))
plt.scatter(df.sqft_living, df.price, edgecolors='white', s=100)
plt.ticklabel_format(style='plain')
plt.xlabel("Square Feet (Living)")
plt.ylabel("Price")
plt.title("Price vs Square Feet (Living)")
# Out:
# Text(0.5, 1.0, 'Price vs Square Feet (Living)')

# %% [markdown]
# The price of the house increases as the living space increases. The most expensive ones have more than 10000 square feet.

# %% [markdown]
# ### How the price is affected by the square feet (total) of the house?

# %%
plt.figure(figsize=(12, 8))
plt.scatter((df['sqft_living']+df['sqft_basement']),df.price, edgecolors='white', s=100)
plt.title("Total Sqft vs Price ")
plt.ticklabel_format(style='plain')
plt.xlabel("Total Sqft")
plt.ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %% [markdown]
# As mentioned above, the price of the house increases as the overal space increases. The most expensive ones have more than 10000 square feet and the most expensive ones are those with more than 15000 square feet.

# %% [markdown]
# ## Location (Latitude and Longitude)

# %% [markdown]
# ### Where are the houses located?

# %%
plt.figure(figsize=(10,10))
jp = sns.jointplot(x=df.lat.values, y=df.long.values, height=10)
jp.ax_joint.set_ylabel('Longitude', fontsize=12)
jp.ax_joint.set_xlabel('Latitude', fontsize=12)
plt.show()

# %%
round((df[(df['lat'] > 47.5) & (df['lat'] < 47.8) & (df['long'] > -122.4) & (df['long'] < -122.2)].shape[0] / df.shape[0])*100, 2)
# Out:
# 41.2

# %% [markdown]
# According to the dataset, we have latitude and longitude on the dataset for each house. Most houses (41.2%) are located between latitude 47.5 and 47.8 and between longitude -122.4 and -122.2.

# %% [markdown]
# ### How the price is affected by the location of the house?

# %%
plt.figure(figsize=(12, 8))
plt.scatter(df.lat.values, df.price, edgecolors='white', s=100)
plt.ticklabel_format(style='plain')
plt.xlabel("Latitude")
plt.ylabel("Price")
plt.title("Price vs Latitude")
# Out:
# Text(0.5, 1.0, 'Price vs Latitude')

# %%
plt.figure(figsize=(12, 8))
plt.scatter(df.long.values, df.price, edgecolors='white', s=100)
plt.ticklabel_format(style='plain')
plt.xlabel("Longitude")
plt.ylabel("Price")
plt.title("Price vs Longitude")
# Out:
# Text(0.5, 1.0, 'Price vs Longitude')

# %%
plt.figure(figsize=(12, 8))
plt.scatter(df.long.values, df.price, edgecolors='white', s=100)
plt.ticklabel_format(style='plain')
plt.xlabel("Longitude")
plt.ylabel("Price")
plt.title("Price vs Longitude")
# Out:
# Text(0.5, 1.0, 'Price vs Longitude')

# %% [markdown]
# As mentioned before, the most expensive ones are those with latitude between 47.5 and 47.8 and longitude between -122.2 and -122.4.

# %% [markdown]
# ## Zipcode

# %% [markdown]
# ### Which zipcodes have the most houses?

# %%
df['zipcode'].value_counts().plot(kind='bar', figsize=(15,5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# Most houses are located in the zipcode 98103, followed by 98038 and 98115.

# %% [markdown]
# ### How the price is affected by the zipcode of the house?

# %%
plt.figure(figsize=(12, 8))
plt.scatter(df.zipcode, df.price, edgecolors='white', s=100)
plt.title("Zipcode vs Price ")
plt.ticklabel_format(style='plain')
plt.xlabel("Zipcode")
plt.ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %% [markdown]
# The price of the house depends on the zipcode location. The most expensive ones are those with zipcode 98039, followed by 98004 and 98040.

# %% [markdown]
# ## Waterfront

# %% [markdown]
# ### How many houses have a waterfront?

# %%
df['waterfront'].value_counts().plot(kind='bar', figsize=(15,5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# Most houses don't have a waterfront.

# %% [markdown]
# ### How the price is affected by the waterfront of the house?

# %%
plt.figure(figsize=(12, 8))
plt.scatter(df.waterfront, df.price, edgecolors='white', s=100)
plt.title("Waterfront vs Price ")
plt.ticklabel_format(style='plain')
plt.xlabel("Waterfront")
plt.ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %% [markdown]
# It's not clear if the price of the house depends on the waterfront. The most expensive ones are those without a waterfront.

# %% [markdown]
# ## View

# %% [markdown]
# ### How many houses have a view?

# %%
df['view'].value_counts().plot(kind='bar', figsize=(15,5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# Most houses don't have a view.

# %% [markdown]
# ### How the price is affected by the view of the house?

# %%
plt.figure(figsize=(12, 8))
plt.scatter(df.view, df.price, edgecolors='white', s=100)
plt.title("View vs Price ")
plt.ticklabel_format(style='plain')
plt.xlabel("View")
plt.ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %% [markdown]
# The most expensive ones are those more than 2 views.

# %% [markdown]
# # Corealtion

# %% [markdown]
# ## Is there a correlation between the price and common factors?

# %%
df_corr = df[['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_basement', 'floors', 'waterfront', 'view', 'yr_built', 'yr_renovated', 'zipcode']]

# %%
df_corr.corr()['price'].sort_values()
# Out:
# zipcode         -0.053203
# yr_built         0.054012
# yr_renovated     0.126434
# floors           0.256794
# waterfront       0.266369
# bedrooms         0.308350
# sqft_basement    0.323816
# view             0.397293
# bathrooms        0.525138
# sqft_living      0.702035
# price            1.000000
# Name: price, dtype: float64

# %% [markdown]
# There is a correlation between the price and the square feet of the house, the number of bathrooms and bedrooms and the view.

# %% [markdown]
# ### Heatmap

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(df_corr.corr(), cmap='coolwarm', annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# The heatmap shows the correlation between the price and the common factors, as well as the correlation between the common factors. The most correlated factors are the square feet of the house and the number of bathrooms and bedrooms. The number of bathrooms are correlated with the year built and the year renovated.
#
# The price of the house is not correlated with the year built and the year renovated, but it's correlated with the square feet of the house, the number of bathrooms and bedrooms and the view.

# %% [markdown]
# # Price prediction - ML model

# %% [markdown]
# ## Pipeline

# %%
from sklearn.model_selection import train_test_split

# %%
X = df[['bedrooms', 'bathrooms', 'sqft_living', 'sqft_basement', 'floors', 'waterfront', 'view', 'yr_built', 'yr_renovated', 'zipcode']]
y = df['price']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn import metrics

# %%
model_pipeline = [LinearRegression(),
                  Lasso(alpha=0.01),
                  RandomForestRegressor(),
                  GradientBoostingRegressor()]

# %%
model_list = ['Linear Regression', 'Lasso Regression', 'Random Forest', 'Gradient Boosting']
score_list = []
mae_list = []
mse_list = []
rmse_list = []

# %%
for model in model_pipeline:
    model.fit(X_train, y_train)
    predictions = model.predict(X_test)
    score_list.append(model.score(X_test, y_test))
    mae_list.append(metrics.mean_absolute_error(y_test, predictions))
    mse_list.append(metrics.mean_squared_error(y_test, predictions))
    rmse_list.append(np.sqrt(metrics.mean_squared_error(y_test, predictions)))

# %%
results_df = pd.DataFrame({'Model': model_list, 'Score': score_list, 'MAE': mae_list, 'MSE': mse_list, 'RMSE': rmse_list})

# %%
results_df
# Out:
#                Model     Score            MAE           MSE           RMSE
# 0  Linear Regression  0.616695  150866.137228  5.229489e+10  228680.766367
# 1   Lasso Regression  0.616695  150866.139126  5.229489e+10  228680.770519
# 2      Random Forest  0.802999   87916.959103  2.687719e+10  163942.643446
# 3  Gradient Boosting  0.790748  105237.206521  2.854856e+10  168963.179962

# %% [markdown]
# Based on the 'Score', the best model is the Random Forest, followed by the Gradient Boosting Regressor for the initial model.

# %% [markdown]
# ## Fine-tuning the model

# %% [markdown]
# ### Random Forest

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {'n_estimators': [100, 400, 800],
              'max_depth': [None, 2, 5],
              'min_samples_split': [2, 3, 7],
              'min_samples_leaf': [2, 5, 8],
              'n_jobs': [-1]}

# %%
grid = GridSearchCV(RandomForestRegressor(), param_grid, verbose=3)

# %%
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 81 candidates, totalling 405 fits
# [CV 1/5] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100, n_jobs=-1;, score=0.798 total time=   3.4s
# [CV 2/5] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100, n_jobs=-1;, score=0.752 total time=   0.7s
# [CV 3/5] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100, n_jobs=-1;, score=0.802 total time=   0.7s
# [CV 4/5] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100, n_jobs=-1;, score=0.769 total time=   0.7s
# [CV 5/5] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100, n_jobs=-1;, score=0.782 total time=   0.7s
# [CV 1/5] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=400, n_jobs=-1;, score=0.799 total time=   2.5s
# [CV 2/5] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=400, n_jobs=-1;, score=0.755 total time=   2.7s
# ...

# %%
grid.best_params_
# Out:
# {'max_depth': None,
#  'min_samples_leaf': 2,
#  'min_samples_split': 7,
#  'n_estimators': 400,
#  'n_jobs': -1}

# %%
grid.best_estimator_
# Out:
# RandomForestRegressor(min_samples_leaf=2, min_samples_split=7, n_estimators=400,
#                       n_jobs=-1)

# %%
grid_predictions = grid.predict(X_test)

# %%
print('Score:', grid.score(X_test, y_test))
print('MAE:', metrics.mean_absolute_error(y_test, grid_predictions))
print('MSE:', metrics.mean_squared_error(y_test, grid_predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, grid_predictions)))
# Out:
# Score: 0.8101657390205323
# MAE: 86639.30574874692
# MSE: 25899366299.320713
# RMSE: 160932.8005700538

# %% [markdown]
# ### Gradient Boosting

# %%
clf = GradientBoostingRegressor(n_estimators = 500, max_depth = 5, min_samples_split = 2, learning_rate = 0.1, loss = 'ls')

# %%
clf.fit(X_train, y_train)
# Out:
# GradientBoostingRegressor(max_depth=5, n_estimators=500)

# %%
clf_predictions = clf.predict(X_test)

# %%
print('Score:', clf.score(X_test, y_test))
print('MAE:', metrics.mean_absolute_error(y_test, clf_predictions))
print('MSE:', metrics.mean_squared_error(y_test, clf_predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, clf_predictions)))
# Out:
# Score: 0.8543490578483448
# MAE: 78125.3111952187
# MSE: 19871371390.830734
# RMSE: 140965.85186076356

# %% [markdown]
# After fine-tuning the model, the best model is the Gradient Boosting Regressor with a score of 0.85 vs the Random Forest with a score of 0.81.
